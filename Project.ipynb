# %%
from tensorflow import keras

# Load your model
model = keras.models.load_model("latest_crop_TS_model.h5")

# Check summary
model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 from tensorflow import keras
#       3 # Load your model
# ----> 4 model = keras.models.load_model("latest_crop_TS_model.h5")
#       6 # Check summary
#       7 model.summary()
#
# File ~\miniconda3\envs\myenv\lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
# ...

# %%
pip install "tensorflow==2.10"
# Out:
# ...
#    ---------------------------------------- 0.0/455.9 MB ? eta -:--:--
#    ---------------------------------------- 0.8/455.9 MB 8.3 MB/s eta 0:00:55
#    ---------------------------------------- 1.6/455.9 MB 5.6 MB/s eta 0:01:22
#    ---------------------------------------- 2.6/455.9 MB 4.6 MB/s eta 0:01:40
#    ---------------------------------------- 3.4/455.9 MB 4.4 MB/s eta 0:01:44
#    ---------------------------------------- 4.2/455.9 MB 4.3 MB/s eta 0:01:45
#    ---------------------------------------- 5.0/455.9 MB 4.3 MB/s eta 0:01:46
#     --------------------------------------- 5.8/455.9 MB 4.2 MB/s eta 0:01:48
#     --------------------------------------- 6.6/455.9 MB 4.2 MB/s eta 0:01:49
#     --------------------------------------- 7.3/455.9 MB 4.1 MB/s eta 0:01:49
#     --------------------------------------- 8.4/455.9 MB 4.1 MB/s eta 0:01:50
#     --------------------------------------- 9.2/455.9 MB 4.0 MB/s eta 0:01:51
# ...

# %%
from tensorflow import keras

# Load the model (skip compile for safety)
model = keras.models.load_model("latest_crop_TS_model.h5", compile=False)

# Check architecture
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (MyLSTM)                      │ (None, 49)                  │          14,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 22)                  │           1,100 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,212 (59.42 KB)
#  Trainable params: 15,212 (59.42 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.models import load_model
model = load_model('latest_crop_TS_model.h5')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from tensorflow.keras.models import load_model
#       2 model = load_model('latest_crop_TS_model.h5')
#
# ModuleNotFoundError: No module named 'tensorflow.keras.models'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
from keras.models import load_model

# Load model (skip compile for legacy H5 models)
model = load_model("latest_crop_TS_model.h5", compile=False)

# Check architecture
model.summary()
# Out:
# C:\Users\HP\miniconda3\envs\myenv\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (MyLSTM)                      │ (None, 49)                  │          14,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 22)                  │           1,100 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,212 (59.42 KB)
# ...

# %%
forcast = []
length=30
n_features=22
first_eval_batch = np.array(train_scaled[-length:])
current_batch = first_eval_batch.reshape(1,length,n_features)

for i in range(60):
    next_features = current_batch[:, -1, :].copy() 
    pred = model.predict(current_batch)
    forcast.append(pred)
    current_batch = np.concatenate([current_batch[:, 1:, :], next_features.reshape(1,1,n_features)], axis=1)

# %%
forcast = np.array(forcast)
forcast = forcast.reshape(60,22)
forcast = scaler.inverse_transform(forcast)
